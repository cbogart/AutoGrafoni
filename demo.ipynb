# %%
# !pip3 install drawsvg
# !pip3 install eng_to_ipa

# %%
import grafoni
from IPython.display import display

display(grafoni.to_svg("""entering surrounding\r\n.And then unto the breach, which all men know--know?""", wrap=200))
# Out:
# Unsupported Character: ?
# None
